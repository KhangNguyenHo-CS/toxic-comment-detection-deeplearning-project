# %% [markdown]
# <a href="https://colab.research.google.com/github/KhangNguyenHo-CS/toxic-comment-detection-deeplearning-project/blob/main/toxic_comment_detection_deeplearning_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Install Libraries

# %%
# !pip install numpy
# !pip install matplotlib
# !pip install tensorflow pandas scikit-learn

# %% [markdown]
# *numpy → numerical computing (arrays, math operations)*
#
# *pandas → data handling (tables, CSV files)*
#
# *matplotlib → data visualization (plots, graphs)*
#
# *scikit-learn → machine learning tools (models, preprocessing, evaluation)*
#
# *tensorflow → deep learning framework (build and train neural networks)*

# %%
import numpy as np
import matplotlib.pyplot as plt
